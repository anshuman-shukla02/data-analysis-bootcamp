# %% [markdown]
# # Module 7: Statistics for Data Analysts
#
# ## Objective
# Understand statistical concepts from a business perspective and learn how to interpret data correctly for decision-making rather than memorizing formulas.

# %%
import pandas as pd
df = pd.read_csv("../data/retail_sales_cleaned.csv")

# %%
df["revenue"] = df["quantity"]*df["unit_price"]

# %%
mean_revenue = df["revenue"].mean()

# %%
median_revenue = df["revenue"].median()

# %%
mean_revenue, median_revenue
# Out:
# (np.float64(904.2857142857143), 480.0)

# %% [markdown]
# # Difference in Mean and Median
#
# ## Mean - affected by outliers (extreme values)
# ## Median - resistant to outliers
#
# By analogy we can say - If billionares increases, the mean will increase but middle class men will not be affected by that.

# %%
# How to know if a business is stable or not?

# %%
# Low std deviation means low volatility - predictable business
# High std deviation means high volatility - risky business

# %%
var = df["revenue"].var()
std_dev = df["revenue"].std()

# %%
var, std_dev
# Out:
# (641828.5714285716, 801.1420419804291)

# %%
df
# Out:
#    order_id  order_date   region     product     category  quantity  \
# 0      1001  2023-01-05    North      Laptop  Electronics       2.0
# 1      1002  2023-01-07    South      Mobile  Electronics       8.0
# 2      1003  2023-01-10     East       Chair    Furniture      10.0
# 3      1003  2023-01-10     East       Chair    Furniture      10.0
# 4      1004  2023-01-15     West       Table    Furniture       8.0
# 5      1005  2023-01-20  Unknown  Headphones  Electronics       8.0
# 6      1006  2023-01-22    South        Sofa    Furniture       1.0
#
#    unit_price  revenue
# 0       750.0   1500.0
# 1       300.0   2400.0
# 2        45.0    450.0
# 3        45.0    450.0
# 4       120.0    960.0
# 5        60.0    480.0
# 6        90.0     90.0

# %%
Q1 = df["revenue"].quantile(0.25)

# %%
Q3 = df["revenue"].quantile(0.75)

# %%
Q1
# Out:
# np.float64(450.0)

# %%
IQR = Q3 - Q1

# %%
lower = Q1 - 1.5*IQR

# %%
upper = Q3 + 1.5*IQR

# %%
outliers = df[(df["revenue"] < lower) | (df["revenue"] > upper)]

# %%
outliers.head()
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, region, product, category, quantity, unit_price, revenue]
# Index: []

# %%
Best_Performer = df["revenue"].quantile(0.90)

# %%
Best_Performer
# Out:
# np.float64(1860.0000000000005)

# %%
Q1, Q3, IQR, lower, upper
# Out:
# (np.float64(450.0),
#  np.float64(1230.0),
#  np.float64(780.0),
#  np.float64(-720.0),
#  np.float64(2400.0))
